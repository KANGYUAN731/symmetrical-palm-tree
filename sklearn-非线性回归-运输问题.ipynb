# %%
import numpy as np
from numpy import genfromtxt
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import linear_model

# %%
data = np.genfromtxt('C:\\Users\\Administrator\\python课程资料\\机器学习\\程序\\回归\\Delivery.csv',delimiter = ',')

# %%
x_data = data[:,:-1]
y_data = data[:,-1]
print(x_data)
print(y_data)
# Out:
# [[100.   4.]
#  [ 50.   3.]
#  [100.   4.]
#  [100.   2.]
#  [ 50.   2.]
#  [ 80.   2.]
#  [ 75.   3.]
#  [ 65.   4.]
#  [ 90.   3.]
#  [ 90.   2.]]
# [9.3 4.8 8.9 6.5 4.2 6.2 7.4 6.  7.6 6.1]

# %%
#创建模型
model = linear_model.LinearRegression()
model.fit(x_data,y_data)
# Out:
# LinearRegression()

# %%
#查看系数
#多元线性回归会生成多个系数
print('coefficients:',model.coef_)
#截距
print('intercept:',model.intercept_)

predict = model.predict(x_data)
print('predict:',predict)
# Out:
# coefficients: [0.0611346  0.92342537]
# intercept: -0.868701466781709
# predict: [8.93845988 4.95830457 8.93845988 7.09160915 4.03487921 5.86891717
#  6.48666954 6.79874892 7.40368852 6.48026316]

# %%
ax = plt.figure().add_subplot(111,projection = '3d')
ax.scatter(x_data[:,0],x_data[:,1],y_data,c='r',s = 100)
x0 = x_data[:,0]
x1 = x_data[:,1]

x0,x1 = np.meshgrid(x0,x1)
z = model.intercept_ + x0*model.coef_[0] + x1*model.coef_[1]

ax.plot_surface(x0,x1,z)
ax.set_label('Miles')
ax.set_label('Num of Deliveries')
ax.set_label('Time')

plt.show()
